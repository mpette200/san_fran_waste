# %%
import pandas as pd

# %%
df = pd.read_csv('../data/san_fran_waste_large.zip')
df
# Out:
#           CaseID                  Opened                  Closed  \
# 0       12701651  07/28/2020 08:08:03 AM  07/28/2020 09:28:00 AM
# 1       12704827  07/28/2020 04:50:02 PM  07/28/2020 05:01:49 PM
# 2       12705439  07/28/2020 07:13:00 PM  07/28/2020 08:05:00 PM
# 3       12705346  07/28/2020 06:41:07 PM                     NaN
# 4       12705917  07/28/2020 11:53:12 PM                     NaN
# ...          ...                     ...                     ...
# 990195   4890831  07/08/2015 08:47:31 AM  07/08/2015 10:00:00 AM
# 990196   4890840  07/08/2015 08:48:41 AM  07/08/2015 06:15:27 PM
# 990197   4890846  07/08/2015 08:49:56 AM  07/08/2015 09:25:47 AM
# 990198   4890847  07/08/2015 08:50:13 AM  07/08/2015 10:23:12 AM
# 990199   4890848  07/08/2015 08:50:18 AM  07/08/2015 09:09:02 AM
#
#                        Updated  Status  \
# 0       07/28/2020 09:28:00 AM  Closed
# 1       07/28/2020 05:01:49 PM  Closed
# 2       07/28/2020 08:05:00 PM  Closed
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 990200 entries, 0 to 990199
# Data columns (total 20 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   CaseID               990200 non-null  int64
#  1   Opened               990200 non-null  object
#  2   Closed               987543 non-null  object
#  3   Updated              990200 non-null  object
#  4   Status               990200 non-null  object
#  5   Status Notes         990174 non-null  object
#  6   Responsible Agency   990200 non-null  object
#  7   Category             990200 non-null  object
#  8   Request Type         990200 non-null  object
#  9   Request Details      990195 non-null  object
#  10  Address              990196 non-null  object
#  11  Street               988022 non-null  object
#  12  Supervisor District  988026 non-null  float64
#  13  Neighborhood         987215 non-null  object
#  14  Police District      987020 non-null  object
# ...

# %%
# %%time
df.iloc[:, 4:].nunique()
# Out:
# CPU times: user 2min 57s, sys: 344 ms, total: 2min 57s
# Wall time: 2min 57s
# Status                      2
# Status Notes            62323
# Responsible Agency        136
# Category                    1
# Request Type               11
# Request Details            23
# Address                123781
# Street                   2462
# Supervisor District        12
# Neighborhood              117
# Police District            10
# Latitude               537603
# Longitude              511837
# Point                  676030
# Source                      7
# Media URL              506584
# dtype: int64

# %%
df.describe(include='all')
# Out:
#               CaseID                  Opened                  Closed  \
# count   9.902000e+05                  990200                  987543
# unique           NaN                  873479                  845879
# top              NaN  09/28/2017 08:43:00 AM  10/09/2019 12:00:00 AM
# freq             NaN                      14                     366
# mean    9.255817e+06                     NaN                     NaN
# std     2.239137e+06                     NaN                     NaN
# min     2.817160e+05                     NaN                     NaN
# 25%     7.199042e+06                     NaN                     NaN
# 50%     9.365622e+06                     NaN                     NaN
# 75%     1.129670e+07                     NaN                     NaN
# max     1.270592e+07                     NaN                     NaN
#
#                        Updated  Status   Status Notes Responsible Agency  \
# ...
